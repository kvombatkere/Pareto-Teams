# %% [markdown]
# ### Pareto Teams

# %%
from pareto import *
from utils import *

# %%
#Import data
imdb_experts_1, imdb_tasks_1, imdb_costs_1 = import_pickled_datasets('imdb', 1)

numExperts = 75
task_index = 8

#Initialize Pareto Test object
paretoTest = paretoCoverageCost(task=imdb_tasks_1[task_index], 
                                n_experts = imdb_experts_1[:numExperts],
                                costs = imdb_costs_1, size_univ = 24, budget=45)

# %%
# cov_utility = 1
# epsilon_val = 0.01
# cost_bound = 100
# experts_solution_list = paretoTest.submodularWithBudget(cov_utility, cost_bound, epsilon_val)
# print(experts_solution_list)


experts_solution_list, solution_skills, sol_coverage, sol_cost = paretoTest.plainGreedy()

# %%
experts_solution_list, solution_skills, sol_coverage, sol_cost = paretoTest.greedyPlus()

# %%
experts_solution_list, solution_skills, sol_coverage, sol_cost = paretoTest.twoGuessPlainGreedy()
