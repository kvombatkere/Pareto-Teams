# %% [markdown]
# ### Pareto Teams

# %%
from pareto import *
from utils import *

# %%
#Import data
imdb_experts_1, imdb_tasks_1, imdb_costs_1 = import_pickled_datasets('imdb', 1)

# %%
paretoTest = paretoCoverageCost(task=imdb_tasks_1[0], 
                                n_experts = imdb_experts_1,
                                costs = imdb_costs_1, size_univ = 24)

# %%
cov_utility = 0.9
epsilon_val = 0.1
cost_bound = 100
experts_solution_list = paretoTest.submodularWithBudget(cov_utility, cost_bound, epsilon_val)
